# %% [markdown]
# # **PERFORMING EDA ON SUGARCANE DATASET**

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df= pd.read_csv(r"C:\Users\Rishi kumar\Downloads\List of Countries by Sugarcane Production.csv")

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production (Tons)  \
# 0           0    Brazil  South America       768.678.382
# 1           1     India           Asia       348.448.000
# 2           2     China           Asia       123.059.739
# 3           3  Thailand           Asia        87.468.496
# 4           4  Pakistan           Asia        65.450.704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                  3.668,531        10.226.205             75.167,5
# 1                     260721         4.950.000             70.393,5
# 2                      88287         1.675.215             73.459,1
# 3                  1.264,303         1.336.575             65.442,2
# 4                     324219         1.130.820               57.879

# %%
df.shape
# Out:
# (103, 7)

# %% [markdown]
# # **Data Cleaning**

# %%
#we have to replace decimal in to commas in both productions and both hectare

# %%
df["Production (Tons)"] = df["Production (Tons)"].str.replace(".","")
df["Production per Person (Kg)"] = df["Production per Person (Kg)"].str.replace(".","").str.replace(",",".")
df["Acreage (Hectare)"] = df["Acreage (Hectare)"].str.replace(".","")
df["Yield (Kg / Hectare)"] = df["Yield (Kg / Hectare)"].str.replace(".","").str.replace(",",".")

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production (Tons)  \
# 0           0    Brazil  South America         768678382
# 1           1     India           Asia         348448000
# 2           2     China           Asia         123059739
# 3           3  Thailand           Asia          87468496
# 4           4  Pakistan           Asia          65450704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                   3668.531          10226205              75167.5
# 1                     260721           4950000              70393.5
# 2                      88287           1675215              73459.1
# 3                   1264.303           1336575              65442.2
# 4                     324219           1130820                57879

# %%
#don't want any space in header
df.rename(columns= {"Production (Tons)": "Production(Tons)"},inplace =True)
df.rename(columns= {"Production per Person (Kg)": "Production_per_Person(Kg)"},inplace =True)
df.rename(columns= {"Acreage (Hectare)": "Acreage(Hectare)"},inplace =True)
df.rename(columns= {"Yield (Kg / Hectare)": "Yield(Kg/Hectare)"},inplace =True)

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production(Tons)  \
# 0           0    Brazil  South America        768678382
# 1           1     India           Asia        348448000
# 2           2     China           Asia        123059739
# 3           3  Thailand           Asia         87468496
# 4           4  Pakistan           Asia         65450704
#
#   Production_per_Person(Kg) Acreage(Hectare) Yield(Kg/Hectare)
# 0                  3668.531         10226205           75167.5
# 1                    260721          4950000           70393.5
# 2                     88287          1675215           73459.1
# 3                  1264.303          1336575           65442.2
# 4                    324219          1130820             57879

# %%
#check null values
df.isna().sum()
# Out:
# Unnamed: 0                   0
# Country                      0
# Continent                    0
# Production(Tons)             0
# Production_per_Person(Kg)    0
# Acreage(Hectare)             1
# Yield(Kg/Hectare)            1
# dtype: int64

# %%
df[df["Yield(Kg/Hectare)"].isnull()]
# Out:
#     Unnamed: 0   Country Continent Production(Tons) Production_per_Person(Kg)  \
# 99          99  Djibouti    Africa               53                        51
#
#    Acreage(Hectare) Yield(Kg/Hectare)
# 99              NaN               NaN

# %%
#remove this and reset index 
df= df.dropna().reset_index()

# %%
df.head()
# Out:
#    index  Unnamed: 0   Country      Continent Production(Tons)  \
# 0      0           0    Brazil  South America        768678382
# 1      1           1     India           Asia        348448000
# 2      2           2     China           Asia        123059739
# 3      3           3  Thailand           Asia         87468496
# 4      4           4  Pakistan           Asia         65450704
#
#   Production_per_Person(Kg) Acreage(Hectare) Yield(Kg/Hectare)
# 0                  3668.531         10226205           75167.5
# 1                    260721          4950000           70393.5
# 2                     88287          1675215           73459.1
# 3                  1264.303          1336575           65442.2
# 4                    324219          1130820             57879

# %%
#we dont want index and unnamed column
df.drop(["index","Unnamed: 0"], axis=1, inplace= True)

# %%
df.head()
# Out:
#     Country      Continent Production(Tons) Production_per_Person(Kg)  \
# 0    Brazil  South America        768678382                  3668.531
# 1     India           Asia        348448000                    260721
# 2     China           Asia        123059739                     88287
# 3  Thailand           Asia         87468496                  1264.303
# 4  Pakistan           Asia         65450704                    324219
#
#   Acreage(Hectare) Yield(Kg/Hectare)
# 0         10226205           75167.5
# 1          4950000           70393.5
# 2          1675215           73459.1
# 3          1336575           65442.2
# 4          1130820             57879

# %%
df.shape
# Out:
# (102, 6)

# %%
#check data types
df.dtypes
# Out:
# Country                      str
# Continent                    str
# Production(Tons)             str
# Production_per_Person(Kg)    str
# Acreage(Hectare)             str
# Yield(Kg/Hectare)            str
# dtype: object

# %%
#change data type in to float (numerical value)
df["Production(Tons)"] = df["Production(Tons)"].astype(float)
df["Production_per_Person(Kg)"] = df["Production_per_Person(Kg)"].astype(float)
df["Acreage(Hectare)"] = df["Acreage(Hectare)"].astype(float)
df["Yield(Kg/Hectare)"] = df["Yield(Kg/Hectare)"].astype(float)

# %%
df.dtypes
# Out:
# Country                          str
# Continent                        str
# Production(Tons)             float64
# Production_per_Person(Kg)    float64
# Acreage(Hectare)             float64
# Yield(Kg/Hectare)            float64
# dtype: object

# %%
#check unique values in our data
df.nunique()
# Out:
# Country                      102
# Continent                      6
# Production(Tons)             102
# Production_per_Person(Kg)    101
# Acreage(Hectare)             101
# Yield(Kg/Hectare)            102
# dtype: int64

# %% [markdown]
# # **UNIVARIATE ANALYSIS 1 columns**

# %%
df.head()
# Out:
#     Country      Continent  Production(Tons)  Production_per_Person(Kg)  \
# 0    Brazil  South America       768678382.0                   3668.531
# 1     India           Asia       348448000.0                 260721.000
# 2     China           Asia       123059739.0                  88287.000
# 3  Thailand           Asia        87468496.0                   1264.303
# 4  Pakistan           Asia        65450704.0                 324219.000
#
#    Acreage(Hectare)  Yield(Kg/Hectare)
# 0        10226205.0            75167.5
# 1         4950000.0            70393.5
# 2         1675215.0            73459.1
# 3         1336575.0            65442.2
# 4         1130820.0            57879.0

# %% [markdown]
# # **How many countries produce sugarcane from each continent?**

# %%
df["Continent"].value_counts()
# Out:
# Continent
# Africa           38
# Asia             25
# North America    22
# South America    11
# Oceania           4
# Europe            2
# Name: count, dtype: int64

# %%
df["Continent"].value_counts().plot(kind = 'bar', ylabel='no of countries')
# Out:
# <Axes: xlabel='Continent', ylabel='no of countries'>

# %% [markdown]
# # **Distribution of columns**

# %%
#now we analysis on numerical data
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
sns.distplot(df["Production(Tons)"])
plt.subplot(2,2,2)
sns.distplot(df["Production_per_Person(Kg)"])
plt.subplot(2,2,3)
sns.distplot(df["Acreage(Hectare)"])
plt.subplot(2,2,4)
sns.distplot(df["Yield(Kg/Hectare)"])
# Out:
# C:\Users\Rishi kumar\AppData\Local\Temp\ipykernel_12960\2813586313.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Production(Tons)"])
# C:\Users\Rishi kumar\AppData\Local\Temp\ipykernel_12960\2813586313.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
#checking outliers using boxplot
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
sns.boxplot(df["Production(Tons)"])
plt.subplot(2,2,2)
sns.boxplot(df["Production_per_Person(Kg)"])
plt.subplot(2,2,3)
sns.boxplot(df["Acreage(Hectare)"])
plt.subplot(2,2,4)
sns.boxplot(df["Yield(Kg/Hectare)"])
plt.tight_layout()

# %%
df.describe()
# Out:
#        Production(Tons)  Production_per_Person(Kg)  Acreage(Hectare)  \
# count      1.020000e+02                 102.000000      1.020000e+02
# mean       1.850372e+07              112952.435755      2.498981e+05
# std        8.419149e+07              176651.341929      1.137003e+06
# min        1.000000e+00                   0.000000      0.000000e+00
# 25%        6.251875e+04                3671.910000      1.104000e+03
# 50%        1.440044e+06               25572.500000      1.655800e+04
# 75%        6.426824e+06              146384.750000      8.047400e+04
# max        7.686784e+08              951087.000000      1.022620e+07
#
#        Yield(Kg/Hectare)
# count         102.000000
# mean        52628.078431
# std         30504.676683
# min            10.000000
# 25%         29072.025000
# 50%         54108.950000
# 75%         73282.700000
# max        129049.300000

# %% [markdown]
# # **BIVARIATE ANALYSIS 2 columns**

# %%
df.head()
# Out:
#     Country      Continent  Production(Tons)  Production_per_Person(Kg)  \
# 0    Brazil  South America       768678382.0                   3668.531
# 1     India           Asia       348448000.0                 260721.000
# 2     China           Asia       123059739.0                  88287.000
# 3  Thailand           Asia        87468496.0                   1264.303
# 4  Pakistan           Asia        65450704.0                 324219.000
#
#    Acreage(Hectare)  Yield(Kg/Hectare)
# 0        10226205.0            75167.5
# 1         4950000.0            70393.5
# 2         1675215.0            73459.1
# 3         1336575.0            65442.2
# 4         1130820.0            57879.0

# %% [markdown]
# # **Which country produces maximum sugarcane? (using country and production tons column)**

# %%
df_new = df[["Country","Production(Tons)"]].set_index("Country")

# %%
df_new
# Out:
#            Production(Tons)
# Country
# Brazil          768678382.0
# India           348448000.0
# China           123059739.0
# Thailand         87468496.0
# Pakistan         65450704.0
# ...                     ...
# Spain                 394.0
# Lebanon                97.0
# Singapore              50.0
# Samoa                  12.0
# Syria                   1.0
#
# [102 rows x 1 columns]

# %%
df_new["Production(Tons)_percent"]= df_new["Production(Tons)"]*100/df_new["Production(Tons)"].sum()
df_new
# Out:
#            Production(Tons)  Production(Tons)_percent
# Country
# Brazil          768678382.0              4.072729e+01
# India           348448000.0              1.846200e+01
# China           123059739.0              6.520138e+00
# Thailand         87468496.0              4.634389e+00
# Pakistan         65450704.0              3.467809e+00
# ...                     ...                       ...
# Spain                 394.0              2.087551e-05
# Lebanon                97.0              5.139401e-06
# Singapore              50.0              2.649176e-06
# Samoa                  12.0              6.358022e-07
# Syria                   1.0              5.298352e-08
#
# [102 rows x 2 columns]

# %%
#plot a piechart
df_new["Production(Tons)_percent"].plot(kind="pie", autopct="%.2f")
# Out:
# <Axes: >

# %%
df_new["Production(Tons)"].head(10).plot(kind="bar")
# Out:
# <Axes: xlabel='Country'>

# %%
#using seaborn
ax= sns.barplot(data = df.head(10), x = "Country", y="Production(Tons)")
ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)
plt.show()
# Out:
# C:\Users\Rishi kumar\AppData\Local\Temp\ipykernel_12960\2275139943.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator. Otherwise, ticks may be mislabeled.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)

# %% [markdown]
# # **Which country has highest land?**

# %%
#first we have to sort the values then we find highest or smallest
df_acr = df.sort_values("Acreage(Hectare)", ascending = False)

# %%
ax= sns.barplot(data = df_acr.head(10), x = "Country", y="Production(Tons)")
ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)
plt.show()
# Out:
# C:\Users\Rishi kumar\AppData\Local\Temp\ipykernel_12960\844557148.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator. Otherwise, ticks may be mislabeled.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)

# %% [markdown]
# # **Which Country has highest yield per hectare?**

# %%
df_yield = df.sort_values("Yield(Kg/Hectare)", ascending = False)

# %%
ax= sns.barplot(data = df_yield.head(10), x = "Country", y="Yield(Kg/Hectare)")
ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)
plt.show()
# Out:
# C:\Users\Rishi kumar\AppData\Local\Temp\ipykernel_12960\3179245314.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator. Otherwise, ticks may be mislabeled.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)

# %% [markdown]
# Which Country has highest production?

# %%
df_prod = df.sort_values("Production(Tons)", ascending = False)
ax= sns.barplot(data = df_yield.head(10), x = "Country", y="Production(Tons)")
ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)
plt.show()
# Out:
# C:\Users\Rishi kumar\AppData\Local\Temp\ipykernel_12960\3213197977.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator. Otherwise, ticks may be mislabeled.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)

# %% [markdown]
# # **which country has highest production per kg?**

# %%
df_prod = df.sort_values("Production_per_Person(Kg)", ascending = False)
ax= sns.barplot(data = df_yield.head(10), x = "Country", y="Production_per_Person(Kg)")
ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)
plt.show()
# Out:
# C:\Users\Rishi kumar\AppData\Local\Temp\ipykernel_12960\3958479423.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator. Otherwise, ticks may be mislabeled.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)

# %% [markdown]
# Correlation
# closure to 0 not correlated
# closure to -1 negatively correlated
# closure to +1 positevely correlated

# %%
df.corr(numeric_only=True)
# Out:
#                            Production(Tons)  Production_per_Person(Kg)  \
# Production(Tons)                   1.000000                   0.015000
# Production_per_Person(Kg)          0.015000                   1.000000
# Acreage(Hectare)                   0.997550                   0.012557
# Yield(Kg/Hectare)                  0.132812                   0.017999
#
#                            Acreage(Hectare)  Yield(Kg/Hectare)
# Production(Tons)                   0.997550           0.132812
# Production_per_Person(Kg)          0.012557           0.017999
# Acreage(Hectare)                   1.000000           0.113433
# Yield(Kg/Hectare)                  0.113433           1.000000

# %%
#using heat map to show the correlation
sns.heatmap(df.corr(numeric_only=True), annot = True, cmap='Greens')
# Out:
# <Axes: >

# %% [markdown]
# ## **Do countries with highest land produce more sugarcane?**
# Answer:- yes they are correlated

# %%
#usng scatterplot
sns.scatterplot(data = df, x="Acreage(Hectare)", y="Production(Tons)")
# Out:
# <Axes: xlabel='Acreage(Hectare)', ylabel='Production(Tons)'>

# %%
#land increase production increase positive correalted

# %% [markdown]
# ## **Do countries which yield more sugarcane per hectare produces more sugarcane in total? answer :- no, because there is no correlation**

# %%
sns.scatterplot(data = df, x="Yield(Kg/Hectare)", y="Production(Tons)")
# Out:
# <Axes: xlabel='Yield(Kg/Hectare)', ylabel='Production(Tons)'>

# %% [markdown]
# ## **Analysis for Continent**

# %%
df_continent = df.groupby("Continent").sum().drop("Country", axis=1)
df_continent
# Out:
#                Production(Tons)  Production_per_Person(Kg)  Acreage(Hectare)  \
# Continent
# Africa               89681472.0                2332636.293         1439089.0
# Asia                721930425.0                1857769.303        10608319.0
# Europe                   5823.0                    536.000              71.0
# North America       173995947.0                3796081.508         1581983.0
# Oceania              36177574.0                  28593.605          490909.0
# South America       865588126.0                3505531.738        11369236.0
#
#                Yield(Kg/Hectare)
# Continent
# Africa                 2142107.5
# Asia                   1171871.4
# Europe                  131870.9
# North America          1082602.4
# Oceania                 162419.1
# South America           677192.7

# %% [markdown]
# ## **Which continent produces maximum sugarcane?**

# %%
df["Continent"].value_counts()
# Out:
# Continent
# Africa           38
# Asia             25
# North America    22
# South America    11
# Oceania           4
# Europe            2
# Name: count, dtype: int64

# %%
df_continent["Production(Tons)"].sort_values(ascending= False).plot(kind = 'bar')
# Out:
# <Axes: xlabel='Continent'>

# %% [markdown]
# ## **which continent has the highest land for the production of sugar?**

# %%
df_continent["Acreage(Hectare)"].sort_values(ascending= False).plot(kind = 'bar')
# Out:
# <Axes: xlabel='Continent'>

# %% [markdown]
# # **Do number of countries in a Continent effects production of sugarcane?**
# answer:- no because africa has more no of countries but it comes on four number in production.

# %%
df_continent["number_of_countries"] = df.groupby("Continent").count()["Country"]
df_continent
# Out:
#                Production(Tons)  Production_per_Person(Kg)  Acreage(Hectare)  \
# Continent
# Africa               89681472.0                2332636.293         1439089.0
# Asia                721930425.0                1857769.303        10608319.0
# Europe                   5823.0                    536.000              71.0
# North America       173995947.0                3796081.508         1581983.0
# Oceania              36177574.0                  28593.605          490909.0
# South America       865588126.0                3505531.738        11369236.0
#
#                Yield(Kg/Hectare)  number_of_countries
# Continent
# Africa                 2142107.5                   38
# Asia                   1171871.4                   25
# Europe                  131870.9                    2
# North America          1082602.4                   22
# Oceania                 162419.1                    4
# South America           677192.7                   11

# %%
continents_names = df_continent.index.to_list()
sns.lineplot(data = df_continent,x = "number_of_countries", y= "Production(Tons)")
plt.xticks(df_continent["number_of_countries"], continents_names, rotation =90)
plt.show()

# %% [markdown]
# ## **Do continent with highest land produces more sugarcane?**
# (yes)

# %%
df_continent.corr()
# Out:
#                            Production(Tons)  Production_per_Person(Kg)  \
# Production(Tons)                   1.000000                   0.522211
# Production_per_Person(Kg)          0.522211                   1.000000
# Acreage(Hectare)                   0.994897                   0.463215
# Yield(Kg/Hectare)                  0.091201                   0.542961
# number_of_countries                0.109244                   0.540086
#
#                            Acreage(Hectare)  Yield(Kg/Hectare)  \
# Production(Tons)                   0.994897           0.091201
# Production_per_Person(Kg)          0.463215           0.542961
# Acreage(Hectare)                   1.000000           0.111166
# Yield(Kg/Hectare)                  0.111166           1.000000
# number_of_countries                0.132817           0.989712
#
#                            number_of_countries
# Production(Tons)                      0.109244
# Production_per_Person(Kg)             0.540086
# ...

# %% [markdown]
# ## **Production distribution by continent**

# %%
df_continent["Production(Tons)"].plot(kind="pie", autopct= "%.2f")
# Out:
# <Axes: >

# %% [markdown]
# ## **Conclusion**

# %% [markdown]
# ##### The Sugarcane Production analysis provides useful insights into the global production, land utilization, and yield of sugarcane across different countries and continents. Through Exploratory Data Analysis (EDA) using Python, we identified important patterns and relationships in the dataset.
#
# ##### The analysis shows that Brazil, India, and China are among the major sugarcane-producing countries and also have large areas of land dedicated to sugarcane cultivation. A strong positive correlation was observed between production and acreage (0.997), indicating that countries with larger cultivation areas generally produce more sugarcane. However, the correlation between production and yield per hectare (0.132) was weak, showing that higher yield alone does not necessarily result in higher total production.
#
# ##### The analysis also identified Guatemala as having the highest yield per hectare and Paraguay as having the highest production per person. Continental analysis showed that South America has the highest overall sugarcane production, followed by Asia and Africa.
#
# ##### Overall, the project demonstrates how Python, Pandas, Matplotlib, and Seaborn can be used for data cleaning, visualization, correlation analysis, and extracting meaningful insights from agricultural data. These findings can help in understanding production patterns and making better decisions regarding land utilization and agricultural efficiency.
